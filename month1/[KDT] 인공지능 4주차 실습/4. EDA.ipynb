# %% [markdown]
# # 4. Exploratory Data Analysis
#
# **탐색적 데이터 분석을 통해 데이터를 통달해봅시다.** with [Titanic Data](https://www.kaggle.com/c/titanic)
#
# 0. 라이브러리 준비
# 1. 분석의 목적과 변수 확인
# 2. 데이터 전체적으로 살펴보기
# 3. 데이터의 개별 속성 파악하기

# %% [markdown]
# ## 0. 라이브러리 준비

# %%
# 라이브러리 불러오기

import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# 데이터 불러오기

titanic=pd.read_csv("train.csv")

# %% [markdown]
# ## 1. 분석의 목적과 변수 확인

# %%
titanic.head()

# 결측치가 있음을 확인했다.
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## 2. 데이터 전체적으로 살펴보기

# %%
## 데이터 전체를 확인하는 함수 : .describe()
titanic.describe()

# 수치형 데이터에 대해서만 요약하기에 모든 attribute가 표시되지 않는다.
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
## 상관계수 함수 : .corr()

titanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
## 결측치 확인

titanic.isnull().sum()
# Age, Cabin, Embarked에서 결측치 발견
# attribute 별로 결측치에 대한 처리 방법을 구상해야 함
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## 3. 데이터의 개별 속성 파악하기

# %% [markdown]
# ### I. Survived Column

# %%
## 생존자, 사망자 명수는?

print(titanic['Survived'].sum())
print(titanic['Survived'].value_counts())
# Out:
# 342
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
## 생존자수와 사망자수를 Barplot으로 그려보기 sns.countplot()

sns.countplot(x='Survived', data=titanic)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# ## Mission : It's Your Turn!
#
# ### 1. 본문에서 언급된 Feature를 제외하고 유의미한 Feature를 1개 이상 찾아봅시다.
#
# - Hint : Fare? Sibsp? Parch?

# %% [markdown]
# ### 2. [Kaggle](https://www.kaggle.com/datasets)에서 Dataset을 찾고, 이 Dataset에서 유의미한 Feature를 3개 이상 찾고 이를 시각화해봅시다.
#
# 함께 보면 좋은 라이브러리 document
# - [numpy]()
# - [pandas]()
# - [seaborn]()
# - [matplotlib]()

# %%
dbt=pd.read_csv('Diabetes.csv')
dbt
# Out:
#       Country/Region/World  ISO    Sex  Year  \
# 0              Afghanistan  AFG    Men  1980
# 1              Afghanistan  AFG    Men  1981
# 2              Afghanistan  AFG    Men  1982
# 3              Afghanistan  AFG    Men  1983
# 4              Afghanistan  AFG    Men  1984
# ...                    ...  ...    ...   ...
# 13995             Zimbabwe  ZWE  Women  2010
# 13996             Zimbabwe  ZWE  Women  2011
# 13997             Zimbabwe  ZWE  Women  2012
# 13998             Zimbabwe  ZWE  Women  2013
# 13999             Zimbabwe  ZWE  Women  2014
#
#        Age-standardised diabetes prevalence  Lower 95% uncertainty interval  \
# 0                                  0.044712                        0.015339
# 1                                  0.046114                        0.016883
# 2                                  0.047601                        0.018745
# 3                                  0.049173                        0.020375
# ...

# %% [markdown]
# 이 데이터에서 유의미한 Feature 3가지로 연도, 국가, 성별을 예상했다.<br>
# + 1) 연도 별 비만율 추이
# + 2) 한국과 북한의 비만율 비교
# + 3) 한국의 남녀 비만율
#
# 이 세 가지를 살펴볼 예정이다.

# %%
KRdbt.corr()
# Out:
#                                           Year  \
# Year                                  1.000000
# Age-standardised diabetes prevalence  0.763516
# Lower 95% uncertainty interval        0.820347
# Upper 95% uncertainty interval        0.555850
#
#                                       Age-standardised diabetes prevalence  \
# Year                                                              0.763516
# Age-standardised diabetes prevalence                              1.000000
# Lower 95% uncertainty interval                                    0.965504
# Upper 95% uncertainty interval                                    0.909789
#
#                                       Lower 95% uncertainty interval  \
# Year                                                        0.820347
# Age-standardised diabetes prevalence                        0.965504
# Lower 95% uncertainty interval                              1.000000
# Upper 95% uncertainty interval                              0.772988
#
# ...

# %% [markdown]
# 해당 관계성 표에서 Year가 증가함에 따라 Age-standardised diabetes prevalence(비만율)이 증가함을 확인할 수 있다.

# %% [markdown]
# ### 연도 별 비만율 추이

# %%
temp=dbt.groupby('Year').mean()
#plt.plot(temp['Year'], temp['Age-standardised diabetes prevalence'])
plt.plot(temp['Age-standardised diabetes prevalence'])

plt.show()

# %% [markdown]
# 연도를 기준으로 전체 국가의 평균 비만율은 증가함을 확인 할 수 있다.

# %% [markdown]
# ### 한국의 남녀 비만율

# %%
KRdbt=dbt[dbt['Country/Region/World']=='South Korea']
KRdbt
# Out:
#       Country/Region/World  ISO    Sex  Year  \
# 5775           South Korea  KOR    Men  1980
# 5776           South Korea  KOR    Men  1981
# 5777           South Korea  KOR    Men  1982
# 5778           South Korea  KOR    Men  1983
# 5779           South Korea  KOR    Men  1984
# ...                    ...  ...    ...   ...
# 12805          South Korea  KOR  Women  2010
# 12806          South Korea  KOR  Women  2011
# 12807          South Korea  KOR  Women  2012
# 12808          South Korea  KOR  Women  2013
# 12809          South Korea  KOR  Women  2014
#
#        Age-standardised diabetes prevalence  Lower 95% uncertainty interval  \
# 5775                               0.040074                        0.015435
# 5776                               0.042338                        0.017814
# 5777                               0.044683                        0.020004
# 5778                               0.047092                        0.022450
# ...

# %%
plt.plot(KRdbt[KRdbt['Sex']=='Men']['Year'], KRdbt[KRdbt['Sex']=='Men']['Age-standardised diabetes prevalence'])
plt.plot(KRdbt[KRdbt['Sex']=='Men']['Year'], KRdbt[KRdbt['Sex']=='Women']['Age-standardised diabetes prevalence'])

plt.show()

# %% [markdown]
# 우리나라의 남녀 비만율 추이이다.
# 1. 남성의 비만율이 항상 여성보다 높을 것이라 예상했지만 약 1985년부터 남성이 앞서기 시작했다.
# 2. 또한 일관적으로 상승곡선을 이룰 것이라 생각했지만 1998년 경부터 10년 가까이 오히려 비만율이 감소했다.<br>
# 우리나라의 당시 경제상황이나 사회 트렌드 등 원인을 찾아보려 했지만 찾지 못하고 의문으로 남았다.

# %% [markdown]
# ### 한국과 북한의 비만율 비교

# %%
NTdbt=dbt[dbt['Country/Region/World']=='North Korea']
NTdbt
# Out:
#       Country/Region/World  ISO    Sex  Year  \
# 4585           North Korea  PRK    Men  1980
# 4586           North Korea  PRK    Men  1981
# 4587           North Korea  PRK    Men  1982
# 4588           North Korea  PRK    Men  1983
# 4589           North Korea  PRK    Men  1984
# ...                    ...  ...    ...   ...
# 11615          North Korea  PRK  Women  2010
# 11616          North Korea  PRK  Women  2011
# 11617          North Korea  PRK  Women  2012
# 11618          North Korea  PRK  Women  2013
# 11619          North Korea  PRK  Women  2014
#
#        Age-standardised diabetes prevalence  Lower 95% uncertainty interval  \
# 4585                               0.049786                        0.018175
# 4586                               0.049761                        0.019407
# 4587                               0.049771                        0.020944
# 4588                               0.049806                        0.021943
# ...

# %%
plt.plot(KRdbt[KRdbt['Sex']=='Men']['Year'], KRdbt.groupby('Year').mean()['Age-standardised diabetes prevalence'])
plt.plot(KRdbt[KRdbt['Sex']=='Men']['Year'], NTdbt.groupby('Year').mean()['Age-standardised diabetes prevalence'])

plt.legend(['South Korea','North Korea'])

plt.show()

# %% [markdown]
# 한국과 북한의 연도별 비만율 추이를 확인하자 한국은 전반적으로 상승곡선이, 북한은 큰 차이가 없음을 확인할 수 있었다.
